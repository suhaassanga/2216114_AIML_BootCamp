# %% [markdown]
# <a href="https://colab.research.google.com/github/suhaassanga/2216114_AIML_BootCamp/blob/Suhaas-Sanga/MultiLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ****MULTI LINEAR REGRESSION MODEL****

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#step 1
df=pd.read_csv("/content/drive/MyDrive/50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
print(df.dtypes)
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
print(df.isnull().any())
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
#this function shows the count of the categorical data(here it is state column)
df["State"].value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
#Distribution with seaborn 
with sns.plotting_context("notebook",font_scale=2.5):
  g = sns.pairplot(df[['R&D Spend','Administration','Marketing Spend','State','Profit']],hue='State',palette='tab10',size=4)
  g.set(xticklabels=[]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Distribution with seaborn 
with sns.plotting_context("notebook",font_scale=2.5):
  g = sns.pairplot(df[['R&D Spend','Administration','Marketing Spend','State','Profit']],hue='R&D Spend',palette='tab10',size=4)
  g.set(xticklabels=[]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Distribution with seaborn 
with sns.plotting_context("notebook",font_scale=2.5):
  g = sns.pairplot(df[['R&D Spend','Administration','Marketing Spend','State','Profit']],hue='Administration',palette='tab10',size=4)
  g.set(xticklabels=[]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Distribution with seaborn 
with sns.plotting_context("notebook",font_scale=2.5):
  g = sns.pairplot(df[['R&D Spend','Administration','Marketing Spend','State','Profit']],hue='Marketing Spend',palette='tab10',size=4)
  g.set(xticklabels=[]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Distribution with seaborn 
with sns.plotting_context("notebook",font_scale=2.5):
  g = sns.pairplot(df[['R&D Spend','Administration','Marketing Spend','State','Profit']],hue='Profit',palette='tab10',size=4)
  g.set(xticklabels=[]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from typing import ValuesView
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
print(x)
# Out:
# [[165349.2 136897.8 471784.1 'New York']
#  [162597.7 151377.59 443898.53 'California']
#  [153441.51 101145.55 407934.54 'Florida']
#  [144372.41 118671.85 383199.62 'New York']
#  [142107.34 91391.77 366168.42 'Florida']
#  [131876.9 99814.71 362861.36 'New York']
#  [134615.46 147198.87 127716.82 'California']
#  [130298.13 145530.06 323876.68 'Florida']
#  [120542.52 148718.95 311613.29 'New York']
#  [123334.88 108679.17 304981.62 'California']
#  [101913.08 110594.11 229160.95 'Florida']
#  [100671.96 91790.61 249744.55 'California']
#  [93863.75 127320.38 249839.44 'Florida']
#  [91992.39 135495.07 252664.93 'California']
#  [119943.24 156547.42 256512.92 'Florida']
#  [114523.61 122616.84 261776.23 'New York']
#  [78013.11 121597.55 264346.06 'California']
#  [94657.16 145077.58 282574.31 'New York']
#  [91749.16 114175.79 294919.57 'Florida']
#  [86419.7 153514.11 0.0 'New York']
#  [76253.86 113867.3 298664.47 'California']
#  [78389.47 153773.43 299737.29 'New York']
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#Individual implimentation of histograms
df["R&D Spend"].hist()

# %%
df["Marketing Spend"].hist()

# %%
df["State"].hist()

# %%
df["Profit"].hist()

# %%
df["Administration"].hist()

# %%
#Encoding Categorical Data
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[3])],remainder='passthrough')
x=np.array(ct.fit_transform(x))

# %%
print(x)
# Out:
# [[0.0 0.0 1.0 165349.2 136897.8 471784.1]
#  [1.0 0.0 0.0 162597.7 151377.59 443898.53]
#  [0.0 1.0 0.0 153441.51 101145.55 407934.54]
#  [0.0 0.0 1.0 144372.41 118671.85 383199.62]
#  [0.0 1.0 0.0 142107.34 91391.77 366168.42]
#  [0.0 0.0 1.0 131876.9 99814.71 362861.36]
#  [1.0 0.0 0.0 134615.46 147198.87 127716.82]
#  [0.0 1.0 0.0 130298.13 145530.06 323876.68]
#  [0.0 0.0 1.0 120542.52 148718.95 311613.29]
#  [1.0 0.0 0.0 123334.88 108679.17 304981.62]
#  [0.0 1.0 0.0 101913.08 110594.11 229160.95]
#  [1.0 0.0 0.0 100671.96 91790.61 249744.55]
#  [0.0 1.0 0.0 93863.75 127320.38 249839.44]
#  [1.0 0.0 0.0 91992.39 135495.07 252664.93]
#  [0.0 1.0 0.0 119943.24 156547.42 256512.92]
#  [0.0 0.0 1.0 114523.61 122616.84 261776.23]
#  [1.0 0.0 0.0 78013.11 121597.55 264346.06]
#  [0.0 0.0 1.0 94657.16 145077.58 282574.31]
#  [0.0 1.0 0.0 91749.16 114175.79 294919.57]
#  [0.0 0.0 1.0 86419.7 153514.11 0.0]
#  [1.0 0.0 0.0 76253.86 113867.3 298664.47]
# ...

# %%
#DataSplitting into training set and the testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4 )

# %%
#Training the multiple Linear Regression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Predict
y_pred=model.predict(x_test)
y_pred
# Out:
# array([157042.09479905,  53439.14393753, 135554.07187893, 173173.76053295,
#        129276.28955413,  98170.7535079 , 159287.3169705 , 100945.00686237,
#         76575.49158124, 129342.40840287])

# %%
y_test
# Out:
# array([156122.51,  35673.41, 144259.4 , 166187.94, 141585.52,  97483.56,
#        155752.6 , 107404.34,  77798.83, 124266.9 ])

# %%
y_train
# Out:
# array([110352.25, 103282.38,  96778.92, 129917.04, 126992.93, 105008.31,
#         89949.14, 118474.03, 108552.04,  42559.73, 134307.35, 146121.95,
#        122776.86, 101004.64,  71498.49,  64926.08, 105733.54,  97427.84,
#        125370.37,  65200.33,  96712.8 , 132602.65, 191050.39,  69758.98,
#         96479.51, 111313.02, 192261.83, 182901.99,  81229.06,  90708.19,
#         14681.4 ,  99937.59,  81005.76, 149759.96, 152211.77, 108733.99,
#         78239.91, 191792.06, 156991.12,  49490.75])

# %%
print("Predicted value for training data:",model.score(x_train,y_train))
print("Training accuracy:",model.score(x_train,y_train)*100)
# Out:
# Predicted value for training data: 0.9473848999820091
# Training accuracy: 94.73848999820092

# %%
print("Predicted value for testing data:",model.score(x_test,y_test))
print("Testing accuracy:",model.score(x_test,y_test)*100)
# Out:
# Predicted value for testing data: 0.9560357304860514
# Testing accuracy: 95.60357304860514

# %%
y_pred
# Out:
# array([157042.09479905,  53439.14393753, 135554.07187893, 173173.76053295,
#        129276.28955413,  98170.7535079 , 159287.3169705 , 100945.00686237,
#         76575.49158124, 129342.40840287])

# %%
#or

# %%
y_pred = model.predict(x_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[157042.09 156122.51]
#  [ 53439.14  35673.41]
#  [135554.07 144259.4 ]
#  [173173.76 166187.94]
#  [129276.29 141585.52]
#  [ 98170.75  97483.56]
#  [159287.32 155752.6 ]
#  [100945.01 107404.34]
#  [ 76575.49  77798.83]
#  [129342.41 124266.9 ]]

# %%
print(y_pred)
# Out:
# [157042.09  53439.14 135554.07 173173.76 129276.29  98170.75 159287.32
#  100945.01  76575.49 129342.41]

# %%
print(y_test)
# Out:
# [156122.51  35673.41 144259.4  166187.94 141585.52  97483.56 155752.6
#  107404.34  77798.83 124266.9 ]

# %%
len(y_pred)
# Out:
# 10

# %%
accuracy=model.score(x,y)*100
print(accuracy)
# Out:
# 94.96690592038571
